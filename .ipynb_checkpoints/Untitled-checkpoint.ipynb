# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, Polygon
import sklearn
from sklearn.model_selection import train_test_split, GridSearchCV, validation_curve
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
import cartopy.crs as ccrs
from scipy.ndimage import gaussian_filter
import cartopy.io.img_tiles as cimgt
import seaborn as sns
import statsmodels.api as sm
from imblearn.over_sampling import SMOTE
from scipy.stats import probplot
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, roc_curve, roc_auc_score
from sklearn.preprocessing import label_binarize
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp
# 评估模型
from sklearn.metrics import mean_squared_error, r2_score
#DBSCAN 
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import KMeans, DBSCAN, OPTICS, AgglomerativeClustering
from esda.adbscan import ADBSCAN

# CART
from sklearn.tree import DecisionTreeRegressor

# random forest
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.metrics import mean_squared_error, accuracy_score, mean_absolute_error
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
# feature importance
import rfpimp

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from imblearn.over_sampling import SMOTE
import pandas as pd
import shap
# xgboost
import xgboost
from xgboost import XGBRegressor

pd.set_option('display.max_rows', 300) # specifies number of rows to show
pd.options.display.float_format = '{:40,.4f}'.format # specifies default number format to 4 decimal places
plt.style.use('ggplot') # specifies that graphs should use ggplot styling
# %matplotlib inline


df = pd.read_csv('road_collisions_cluster.csv')


# 假设 df 是你的数据框
# 取数据集的前1000行
df_sample = df.head(5000)

# # 删除指定的列
data_X = df_sample.drop(['accident_severity', 'accident_index', 'accident_reference', 'date', 'time', 'geometry','longitude','latitude'], axis=1)
data_Y = df_sample['accident_severity']  # 假设 'data' 实际上是 'df'
# 删除指定的列
# data_X = df.drop(['accident_severity', 'accident_index', 'accident_reference', 'date', 'time', 'geometry'], axis=1)
# data_Y = df['accident_severity']  # 假设 'data' 实际上是 'df'

randomState_dt = 100

# 使用 SMOTE 进行过采样
smote = SMOTE(random_state=42, k_neighbors=2)
X_resampled, Y_resampled = smote.fit_resample(data_X, data_Y)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 55
#      51 plt.style.use('ggplot') # specifies that graphs should use ggplot styling
#      52 get_ipython().run_line_magic('matplotlib', 'inline')
# ---> 55 df = pd.read_csv('road_collisions_cluster.csv')
#      58 # 假设 df 是你的数据框
#      59 # 取数据集的前1000行
#      60 df_sample = df.head(5000)
#
# File F:\Python39\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File F:\Python39\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File F:\Python39\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File F:\Python39\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File F:\Python39\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File F:\Python39\lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File F:\Python39\lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'road_collisions_cluster.csv'

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# 拆分训练集和测试集
X_train, X_test, Y_train, Y_test = train_test_split(X_resampled, Y_resampled, test_size=0.2, random_state=randomState_dt)

# 定义超参数
hyperparameters = {
    'n_estimators': [300, 400, 500, 600, 700],
    'max_depth': [10, 20, 30, 40, 50],
    'min_samples_split': [2, 5, 10],
    'criterion': ['gini', 'entropy']
}

# 初始化随机森林分类器
rf = RandomForestClassifier(random_state=randomState_dt)

# 使用 GridSearchCV 进行超参数调节
clf = GridSearchCV(rf, hyperparameters, cv=5, n_jobs=-1)  # cv=5 for 5 fold cross verification

# 训练模型并找到最佳参数
clf.fit(X_train, Y_train)

print("The best parameter value is: ")
print(clf.best_params_)
print("The best score is: ")
print(clf.best_score_)

# 使用最佳参数训练模型（已经由 GridSearchCV 自动完成）
best_rf_model = clf.best_estimator_

# 在测试集上进行预测
Y_pred = best_rf_model.predict(X_test)

# %%
import geopandas as gpd
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# 假设 data_X 包含 'longitude' 和 'latitude' 列
gdf = gpd.GeoDataFrame(data_X, geometry=gpd.points_from_xy(data_X.longitude, data_X.latitude))

# 将数据集划分为几个空间区域（例如网格）
gdf['region'] = ((gdf.geometry.x // 0.01).astype(int) * 1000 + (gdf.geometry.y // 0.01).astype(int))

# 使用空间区域来划分训练集和测试集
train_gdf, test_gdf = train_test_split(gdf, test_size=0.2, random_state=randomState_dt, stratify=gdf['region'])

# 从地理数据框中提取特征和标签
X_train = train_gdf.drop(['region', 'geometry'], axis=1)
Y_train = data_Y.loc[train_gdf.index]
X_test = test_gdf.drop(['region', 'geometry'], axis=1)
Y_test = data_Y.loc[test_gdf.index]

# 训练模型
rf = RandomForestClassifier(random_state=randomState_dt)
rf.fit(X_train, Y_train)

# 预测
Y_pred = rf.predict(X_test)

# 计算准确率
accuracy = accuracy_score(Y_test, Y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 8
#       5 from sklearn.model_selection import train_test_split
#       7 # 假设 data_X 包含 'longitude' 和 'latitude' 列
# ----> 8 gdf = gpd.GeoDataFrame(data_X, geometry=gpd.points_from_xy(data_X.longitude, data_X.latitude))
#      10 # 将数据集划分为几个空间区域（例如网格）
#      11 gdf['region'] = ((gdf.geometry.x // 0.01).astype(int) * 1000 + (gdf.geometry.y // 0.01).astype(int))
#
# File F:\Python39\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'longitude'

# %%
# 生成混淆矩阵
conf_matrix = confusion_matrix(Y_test, Y_pred)
print("Confusion Matrix for RF:")
print(conf_matrix)

# 计算评估指标
accuracy = accuracy_score(Y_test, Y_pred)
precision = precision_score(Y_test, Y_pred, average='weighted')
recall = recall_score(Y_test, Y_pred, average='weighted')
f1 = f1_score(Y_test, Y_pred, average='weighted')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)

# 生成分类报告
class_report = classification_report(Y_test, Y_pred)
print("Classification Report  for RF:")
print(class_report)
# Out:
# Confusion Matrix for RF:
# [[852   0   2]
#  [  3 757  86]
#  [  1  69 752]]
# Accuracy: 0.9361617763679619
# Precision: 0.936250736677609
# Recall: 0.9361617763679619
# F1 Score: 0.9361277273446649
# Classification Report  for RF:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       854
#            2       0.92      0.89      0.91       846
#            3       0.90      0.91      0.90       822
#
#     accuracy                           0.94      2522
#    macro avg       0.94      0.94      0.94      2522
# weighted avg       0.94      0.94      0.94      2522

# %%
### SHAP 特征重要性分析（rf）

# %%
#### 多类特征重要性分析

# %%
import shap
import numpy as np
import matplotlib.pyplot as plt

# 使用 SHAP 进行特征重要性分析
explainer = shap.TreeExplainer(best_rf_model, X_train, feature_perturbation='interventional')
shap_values = explainer(X_test, check_additivity=False)

# 获取每个类别的 SHAP 值
shap_values_class_1 = shap_values.values[:, :, 0]
shap_values_class_2 = shap_values.values[:, :, 1]
shap_values_class_3 = shap_values.values[:, :, 2]

# 计算每个特征的重要性平均值
shap_mean_class_1 = np.mean(np.abs(shap_values_class_1), axis=0)
shap_mean_class_2 = np.mean(np.abs(shap_values_class_2), axis=0)
shap_mean_class_3 = np.mean(np.abs(shap_values_class_3), axis=0)

# 合并数据
shap_mean_combined = np.vstack([shap_mean_class_1, shap_mean_class_2, shap_mean_class_3]).T

# 特征名
feature_names = X_test.columns

# 设置颜色和类别标签
colors = ['blue', 'red', 'green']
class_labels = ['Fatal', 'Serious', 'Slight']

# 绘制 Class-Specific Bar Plot
fig, ax = plt.subplots(figsize=(10, 8))
width = 0.2  # 柱的宽度
x = np.arange(len(feature_names))  # 特征的 x 轴位置

# 为每个类别绘制柱状图
for i in range(shap_mean_combined.shape[1]):
    ax.barh(x + width * i, shap_mean_combined[:, i], width, label=class_labels[i], color=colors[i])

# 添加特征名到 y 轴
ax.set_yticks(x + width)
ax.set_yticklabels(feature_names)

# 添加标签和标题
ax.set_xlabel("Mean(|SHAP value|) (average impact on model output magnitude)")
ax.set_title("SHAP Feature Importance by Class")
ax.legend()
plt.savefig('./image1/SHAP_Feature_Importance_by_Class.png', dpi=300, bbox_inches='tight')
plt.show()

# 绘制 Overlay SHAP Feature Importance by Class
fig, ax = plt.subplots(figsize=(12, 8))

# 按特征重要性排序
sorted_idx = np.argsort(np.sum(shap_mean_combined, axis=1))[::-1]

# 累积宽度，叠加图形
for i in range(shap_mean_combined.shape[1]):
    ax.barh(feature_names[sorted_idx], shap_mean_combined[sorted_idx, i], label=class_labels[i], color=colors[i])

# 添加标签和标题
ax.set_xlabel("Mean(|SHAP value|) (average impact on model output magnitude)")
ax.set_title("Overlay layer SHAP Feature Importance by Class")
ax.legend()
plt.savefig('./image1/Overlay_layer_SHAP_Feature_Importance_by_Class.png', dpi=300, bbox_inches='tight')
plt.show()

# 计算所有类别 SHAP 值的平均值
shap_values_mean = np.mean(shap_values.values, axis=2)

# 创建一个新的 SHAP Explanation 对象，其中包含综合后的 SHAP 值
shap_values_combined = shap.Explanation(
    values=shap_values_mean,
    base_values=np.mean(shap_values.base_values, axis=1),  # 基线值取平均值
    data=X_test,
    feature_names=X_test.columns
)

# 绘制综合 beeswarm 图，设置 max_display 参数以显示所有特征
plt.figure(figsize=(10, 8))
shap.plots.beeswarm(shap_values_combined, max_display=shap_values_combined.values.shape[1], show=False)
plt.savefig('./image1/beeswarm_plot.png', dpi=300, bbox_inches='tight')
plt.close()

# 绘制条形图以展示变量对模型的影响因素大小，设置 max_display 参数以显示所有特征
plt.figure(figsize=(10, 8))
shap.summary_plot(shap_values_combined, X_test, plot_type="bar", max_display=shap_values_combined.values.shape[1], show=False)
plt.savefig('./image1/summary_plot.png', dpi=300, bbox_inches='tight')
plt.close()
# Out:
# 100%|===================| 7562/7566 [16:26<00:00]

# %% [markdown]
# ### 针对每个伦敦道路碰撞热点进行分析--局部

# %%
df_clusters = pd.read_csv('road_collision_clusters.csv')
df_clusters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27221 entries, 0 to 27220
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   accident_index              27221 non-null  object
#  1   accident_year               27221 non-null  int64
#  2   accident_reference          27221 non-null  object
#  3   junction_location           27221 non-null  int64
#  4   skidding_and_overturning    27221 non-null  int64
#  5   journey_purpose_of_driver   27221 non-null  int64
#  6   sex_of_driver               27221 non-null  int64
#  7   age_of_driver               27221 non-null  int64
#  8   longitude                   27221 non-null  float64
#  9   latitude                    27221 non-null  float64
#  10  accident_severity           27221 non-null  int64
#  11  date                        27221 non-null  object
#  12  day_of_week                 27221 non-null  int64
#  13  time                        27221 non-null  object
#  14  road_type                   27221 non-null  int64
#  15  speed_limit                 27221 non-null  int64
#  16  junction_detail             27221 non-null  int64
#  17  junction_control            27221 non-null  int64
#  18  light_conditions            27221 non-null  int64
#  19  weather_conditions          27221 non-null  int64
#  20  road_surface_conditions     27221 non-null  int64
#  21  special_conditions_at_site  27221 non-null  int64
#  22  hour                        27221 non-null  int64
#  23  geometry                    27221 non-null  object
#  24  index_right                 27221 non-null  int64
#  25  neighbourhood               27221 non-null  object
#  26  neighbourhood_group         0 non-null      float64
#  27  cluster                     27221 non-null  int64
# dtypes: float64(3), int64(19), object(6)
# memory usage: 5.8+ MB

# %%
# Calculate the number of null values in each column
null_counts = df_clusters.isnull().sum()
print(null_counts)
# Out:
# accident_index                    0
# accident_year                     0
# accident_reference                0
# junction_location                 0
# skidding_and_overturning          0
# journey_purpose_of_driver         0
# sex_of_driver                     0
# age_of_driver                     0
# longitude                         0
# latitude                          0
# accident_severity                 0
# date                              0
# day_of_week                       0
# time                              0
# road_type                         0
# speed_limit                       0
# junction_detail                   0
# junction_control                  0
# light_conditions                  0
# weather_conditions                0
# road_surface_conditions           0
# special_conditions_at_site        0
# hour                              0
# geometry                          0
# index_right                       0
# neighbourhood                     0
# neighbourhood_group           27221
# cluster                           0
# dtype: int64

# %%
df_clusters.drop(columns=['neighbourhood_group'], inplace=True)

# %%
df_clusters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27221 entries, 0 to 27220
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   accident_index              27221 non-null  object
#  1   accident_year               27221 non-null  int64
#  2   accident_reference          27221 non-null  object
#  3   junction_location           27221 non-null  int64
#  4   skidding_and_overturning    27221 non-null  int64
#  5   journey_purpose_of_driver   27221 non-null  int64
#  6   sex_of_driver               27221 non-null  int64
#  7   age_of_driver               27221 non-null  int64
#  8   longitude                   27221 non-null  float64
#  9   latitude                    27221 non-null  float64
#  10  accident_severity           27221 non-null  int64
#  11  date                        27221 non-null  object
#  12  day_of_week                 27221 non-null  int64
#  13  time                        27221 non-null  object
#  14  road_type                   27221 non-null  int64
#  15  speed_limit                 27221 non-null  int64
#  16  junction_detail             27221 non-null  int64
#  17  junction_control            27221 non-null  int64
#  18  light_conditions            27221 non-null  int64
#  19  weather_conditions          27221 non-null  int64
#  20  road_surface_conditions     27221 non-null  int64
#  21  special_conditions_at_site  27221 non-null  int64
#  22  hour                        27221 non-null  int64
#  23  geometry                    27221 non-null  object
#  24  index_right                 27221 non-null  int64
#  25  neighbourhood               27221 non-null  object
#  26  cluster                     27221 non-null  int64
# dtypes: float64(2), int64(19), object(6)
# memory usage: 5.6+ MB

# %% [markdown]
# #### Random forest （局部分析）

# %% [markdown]
# #### 检验全局模型是否适用于每个碰撞热点（随机森林- 因为该模型的准确性较高）

# %%
from sklearn.metrics import accuracy_score

# 假设 best_rf_model 已经训练好

for cluster in df_clusters['cluster'].unique():
    df_cluster = df_clusters[df_clusters['cluster'] == cluster]
    
    # 打印当前聚类的前几行数据
    print(f"Cluster {cluster} data sample:")
    #print(df_cluster.head())
    
    # 删除指定的列，确保特征与训练数据集的特征一致
    data_X_cluster = df_cluster.drop(['accident_severity', 'accident_index', 'accident_reference', 'date', 'time', 'geometry', 'neighbourhood', 'index_right', 'cluster','longitude','latitude'], axis=1)
    
    # 提取真实标签
    true_labels = df_cluster['accident_severity']
    
    # 使用训练好的模型进行预测
    predictions = best_rf_model.predict(data_X_cluster)
    
    # 计算准确性
    accuracy = accuracy_score(true_labels, predictions)
    print(f"Accuracy on cluster {cluster}: {accuracy}")
# Out:
# Cluster 2 data sample:
# Accuracy on cluster 2: 0.7731626610936956
# Cluster 1 data sample:
# Accuracy on cluster 1: 0.8025728987993139
# Cluster 3 data sample:
# Accuracy on cluster 3: 0.8049490538573508
# Cluster 0 data sample:
# Accuracy on cluster 0: 0.7787367595135347

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, precision_score, recall_score, f1_score
from imblearn.over_sampling import SMOTE
import pickle
import shap
import numpy as np
import matplotlib.pyplot as plt
import os

# 定义超参数
hyperparameters = {
    'n_estimators': [300, 400, 500, 600, 700],
    'max_depth': [10, 20, 30, 40, 50],
    'min_samples_split': [2, 5, 10]
}

# 随机数种子
randomState_dt = 100

# 保存结果的列表
results_list = []

# 确保保存图像的目录存在
os.makedirs('./image1', exist_ok=True)

# 遍历每个聚类类别
for cluster in df_clusters['cluster'].unique():
    try:
        # 选择当前聚类类别的数据
        df_cluster = df_clusters[df_clusters['cluster'] == cluster]
        
        # 随机选择1000个样本（如果超过1000）
        if len(df_cluster) > 1000:
            df_cluster = df_cluster.sample(n=1000, random_state=randomState_dt)
        
        # 删除指定的列
        data_X = df_cluster.drop(['accident_severity', 'accident_index', 'accident_reference', 'date', 'time', 'geometry', 'neighbourhood', 'index_right', 'cluster','longitude','latitude'], axis=1)
        data_Y = df_cluster['accident_severity']
        
        # 使用 SMOTE 进行过采样，调整 k_neighbors 参数
        smote = SMOTE(random_state=42, k_neighbors=min(2, min(data_Y.value_counts()) - 1))
        X_resampled, Y_resampled = smote.fit_resample(data_X, data_Y)
        
        # 拆分训练集和测试集
        X_train, X_test, Y_train, Y_test = train_test_split(X_resampled, Y_resampled, test_size=0.2, random_state=randomState_dt)
        
        # 初始化随机森林分类器
        rf = RandomForestClassifier(random_state=randomState_dt)
        
        # 使用 GridSearchCV 进行超参数调节
        clf = GridSearchCV(rf, hyperparameters, cv=5, n_jobs=-1)  # cv=5 for 5-fold cross-validation
        
        # 训练模型
        clf.fit(X_train, Y_train)
        
        # 使用最佳参数训练模型并进行预测
        best_rf_model = clf.best_estimator_
        Y_pred = best_rf_model.predict(X_test)

        # 评估模型
        accuracy = accuracy_score(Y_test, Y_pred)
        report = classification_report(Y_test, Y_pred)
        precision = precision_score(Y_test, Y_pred, average='weighted')
        recall = recall_score(Y_test, Y_pred, average='weighted')
        f1 = f1_score(Y_test, Y_pred, average='weighted')

        # 打印训练和测试集上的 R² 值
        train_r2 = best_rf_model.score(X_train, Y_train)
        test_r2 = best_rf_model.score(X_test, Y_test)

        # 保存结果
        results = {
            'cluster': cluster,
            'best_params': clf.best_params_,
            'best_score': clf.best_score_,
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'f1_score': f1,
            'report': report,
            'train_r2': train_r2,
            'test_r2': test_r2,
            'best_rf_model': best_rf_model,
            'X_train': X_train,
            'X_test': X_test
        }
        
        # 添加到结果列表
        results_list.append(results)

        # 使用 SHAP 进行特征重要性分析
        explainer = shap.TreeExplainer(best_rf_model, X_train, feature_perturbation='interventional')
        shap_values = explainer(X_test, check_additivity=False)

        # 计算所有类别 SHAP 值的平均值
        shap_values_mean = np.mean(shap_values.values, axis=2)

        # 创建一个新的 SHAP Explanation 对象，其中包含综合后的 SHAP 值
        shap_values_combined = shap.Explanation(
            values=shap_values_mean,
            base_values=np.mean(shap_values.base_values, axis=1),  # 基线值取平均值
            data=X_test,
            feature_names=X_test.columns
        )

        # 绘制综合 beeswarm 图，设置 max_display 参数以显示所有特征
        plt.figure(figsize=(10, 8))
        shap.plots.beeswarm(shap_values_combined, max_display=shap_values_combined.values.shape[1], show=False)
        plt.savefig(f'./image/beeswarm_plot_cluster_{cluster}.png', dpi=300, bbox_inches='tight')
        plt.close()

        # 绘制条形图以展示变量对模型的影响因素大小，设置 max_display 参数以显示所有特征
        plt.figure(figsize=(10, 8))
        shap.summary_plot(shap_values_combined, X_test, plot_type="bar", max_display=shap_values_combined.values.shape[1], show=False)
        plt.savefig(f'./image/summary_plot_cluster_{cluster}.png', dpi=300, bbox_inches='tight')
        plt.close()
    
    except ValueError as e:
        print(f"Cluster {cluster} - Error: {e}")
        results_list.append({
            'cluster': cluster,
            'error': str(e)
        })

# 保存结果到文件
with open('results.pkl', 'wb') as f:
    pickle.dump(results_list, f)

# 输出所有聚类类别的结果
for result in results_list:
    print(f"Cluster {result['cluster']} Results:")
    for key, value in result.items():
        if key not in ['best_rf_model', 'X_train', 'X_test']:
            print(f"{key}: {value}")
    print("\n")
# Out:
# 100%|===================| 1463/1464 [01:05<00:00]
# Cluster 2 Results:
# cluster: 2
# best_params: {'max_depth': 30, 'min_samples_split': 2, 'n_estimators': 300}
# best_score: 0.9158022323450279
# accuracy: 0.9010309278350516
# precision: 0.9015217253810639
# recall: 0.9010309278350516
# f1_score: 0.9012058507889974
# report:               precision    recall  f1-score   support
#
#            1       1.00      0.99      1.00       158
#            2       0.84      0.86      0.85       159
#            3       0.87      0.85      0.86       168
#
#     accuracy                           0.90       485
#    macro avg       0.90      0.90      0.90       485
# weighted avg       0.90      0.90      0.90       485
#
# train_r2: 1.0
# test_r2: 0.9010309278350516
#
#
# Cluster 1 Results:
# cluster: 1
# best_params: {'max_depth': 30, 'min_samples_split': 2, 'n_estimators': 600}
# best_score: 0.9100909842845326
# accuracy: 0.9186507936507936
# precision: 0.9186823161592975
# recall: 0.9186507936507936
# f1_score: 0.9185344738383897
# report:               precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99       168
#            2       0.88      0.85      0.87       150
#            3       0.88      0.90      0.89       186
#
#     accuracy                           0.92       504
#    macro avg       0.92      0.92      0.92       504
# weighted avg       0.92      0.92      0.92       504
#
# train_r2: 1.0
# test_r2: 0.9186507936507936
#
#
# Cluster 3 Results:
# cluster: 3
# best_params: {'max_depth': 30, 'min_samples_split': 2, 'n_estimators': 700}
# best_score: 0.930392156862745
# accuracy: 0.9490196078431372
# precision: 0.9491198809660991
# recall: 0.9490196078431372
# f1_score: 0.9489846190698236
# report:               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       168
#            2       0.93      0.91      0.92       163
#            3       0.92      0.94      0.93       179
#
#     accuracy                           0.95       510
#    macro avg       0.95      0.95      0.95       510
# weighted avg       0.95      0.95      0.95       510
#
# train_r2: 1.0
# test_r2: 0.9490196078431372
#
#
# Cluster 0 Results:
# cluster: 0
# best_params: {'max_depth': 30, 'min_samples_split': 2, 'n_estimators': 400}
# best_score: 0.9147808318502406
# accuracy: 0.9077868852459017
# precision: 0.9098881976370747
# recall: 0.9077868852459017
# f1_score: 0.9076979822677694
# report:               precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00       158
#            2       0.83      0.90      0.86       154
#            3       0.91      0.83      0.87       176
#
#     accuracy                           0.91       488
#    macro avg       0.91      0.91      0.91       488
# weighted avg       0.91      0.91      0.91       488
#
# train_r2: 1.0
# test_r2: 0.9077868852459017
